# %% [markdown]
# # Análise de dados do Ocomon

# %% [markdown]
# ## Os dados aqui importados já estão tratatos e com os devidos novos campos adicionados

# %% [markdown]
# #### Bibliotecas:

# %%
import pandas as pd

# %% [markdown]
# #### Carregando o arquivo:

# %%
# Import DataFrame
# if csv don't are split per ",", then we've to add a new args to method, 
# ex: read_csv('x.csv', sep=';')

#the pattern code to decode file in read_csv() method is utf-8
# if the file don't use this enconde, use enconding='cp1252'
df = pd.read_csv('ocomon.csv')

# %%
#show the 5 first line from dataframe
df.head()
# Out:
#      ID                                              DESCR   EQUIP  \
# 0  1397           configuracao ap consultorio odontologico       1
# 1  6133                      configuracao de ap para o lib -999999
# 2   883                     configurar ap para a fisicaccn -999999
# 3  1086   da solicitacao stcnome francilane maria l oli... -999999
# 4  1620   da solicitacao stcnome rangel de sales meirel... -999999
#
#                           CONT  D_YEAR_OPEN  D_MOTH_OPEN  D_DAY_OPEN  \
# 0                       kelson         2012            2          28
# 1                     gilberto         2013            7          12
# 2                       alguem         2012            1          11
# 3  francilane maria l oliveira         2012            1          30
# 4     rangel de sales meireles         2012            2           2
#
#    D_HOUR_OPEN  D_MIN_OPEN  D_SEG_OPEN  ...  \
# 0           15           6          23  ...
# 1            9          13           1  ...
# 2           10           8          24  ...
# 3            9           0          29  ...
# 4           11          54          15  ...
#
#                                               PROB  \
# 0                      configuracao de equipamento
# 1                      configuracao de equipamento
# 2                      configuracao de equipamento
# 3                       sem acesso a internet rede
# 4  solicitacao de materiais cabos de rede e demais
#
#                                               P_DESC  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  solicitacao de materiais diversos cabos de red...
#
#                                                PLACE           U_NAME  \
# 0             nti nucleo de tecnologia da informacao    kelson soares
# 1                                            ccs lib       marcio igo
# 2                         ccn departamento de fisica  mario cristiano
# 3                                 cca biblioteca ial       julio froz
# 4  proplan coordenadoria de programas planos e pr...       julio froz
#
#                                             SOL_PROB  \
# 0                         equipamento desconfigurado
# 1                      descricao tecnica do problema
# 2                        configuracao de acess point
# 3  cabo de rede desconectado porta do switch quei...
# 4  liguei para o solicitante e falei para ele vir...
#
#                                                SOLUT    I_NAME       T_EQUIP  \
# 0  foi feita a devida configuracao do equipamento...  teresina            ap
# 1                         solucao para este problema  teresina            ap
# 2                        configuracao de acess point  teresina            ap
# 3            mudar o cabo para outra porta do switch  teresina  cabo de rede
# 4  liguei para o solicitante e falei para ele vir...       NaN  cabo de rede
#
#          T_PROB T_ESPC
# 0           N.A    N.A
# 1           N.A    N.A
# 2           N.A    N.A
# 3  Cabo de rede    N.A
# 4  Cabo de rede    N.A
#
# [5 rows x 26 columns]

# %%
#show the last 5 line from the dataframe
df.tail()
# Out:
#           ID                                              DESCR   EQUIP  \
# 15822   7898                   switch presente na prex queimada -999999
# 15823  14443                          troca de switchvigilancia -999999
# 15824   1141  verificar switch do agricola rack c switch poi... -999999
# 15825   1131            verificar switch fora no bloco de modas -999999
# 15826   1528                verificar switch fora no nppm rack  -999999
#
#              CONT  D_YEAR_OPEN  D_MOTH_OPEN  D_DAY_OPEN  D_HOUR_OPEN  \
# 15822        ryan         2013           11          25           11
# 15823       zezao         2017           10           2           10
# 15824  secretaria         2012            2           2           10
# 15825      kelson         2012            2           2            7
# 15826      kelson         2012            3           8           10
#
#        D_MIN_OPEN  D_SEG_OPEN  ...  \
# 15822           4          36  ...
# 15823          22           4  ...
# 15824          24          57  ...
# 15825          48          42  ...
# 15826          53          18  ...
#
#                                                     PROB  P_DESC  \
# 15822                         sem acesso a internet rede     NaN
# 15823  instalacao e manutencao da infraestrutura de t...     NaN
# 15824                        configuracao de equipamento     NaN
# 15825                         sem acesso a internet rede     NaN
# 15826                         sem acesso a internet rede     NaN
#
#                                               PLACE                 U_NAME  \
# 15822                prex secretaria administrativa  ryan barbosa monteiro
# 15823                  0 local ainda nao cadastrado  mauricio ribeiro sena
# 15824                                  cca agricola          kelson soares
# 15825                      cce departamento de moda          kelson soares
# 15826  ccs nucleo de pesquisa de plantas medicinais          kelson soares
#
#                                      SOL_PROB  \
# 15822                         switch queimada
# 15823           descricao tecnica do problema
# 15824  switch estava problema na configuracao
# 15825           descricao tecnica do problema
# 15826                  estava sem energia no
#
#                                                    SOLUT    I_NAME T_EQUIP  \
# 15822  a switch queimada foi substituida e a nova foi...  teresina  switch
# 15823                         solucao para este problema  teresina  switch
# 15824          foi feita a devida configuracao na switch  teresina  switch
# 15825  substituir o switch pois o switch no local da ...  teresina  switch
# 15826  aguardado a energia voltar para o problema ser...  teresina  switch
#
#       T_PROB T_ESPC
# 15822    N.A    N.A
# 15823    N.A    N.A
# 15824    N.A    N.A
# 15825    N.A    N.A
# 15826    N.A    N.A
#
# [5 rows x 26 columns]

# %%
#show how many registres has in each column
df.count()
# Out:
# ID              15827
# DESCR           15827
# EQUIP           15827
# CONT            15458
# D_YEAR_OPEN     15827
# D_MOTH_OPEN     15827
# D_DAY_OPEN      15827
# D_HOUR_OPEN     15827
# D_MIN_OPEN      15827
# D_SEG_OPEN      15827
# D_YEAR_CLOSE    15827
# D_MOTH_CLOSE    15827
# D_DAY_CLOSE     15827
# D_HOUR_CLOSE    15827
# D_MIN_CLOSE     15827
# D_SEG_CLOSE     15827
# PROB            15825
# P_DESC           5878
# PLACE           15809
# U_NAME          15827
# SOL_PROB        14213
# SOLUT           14214
# I_NAME          15491
# T_EQUIP         15827
# T_PROB          15827
# T_ESPC          15827
# dtype: int64
